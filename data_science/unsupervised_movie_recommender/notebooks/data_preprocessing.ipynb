# %% [markdown]
# In this notebook, we do the pre-processing necessary for our movie recommender flask app.
#
# This entails:
# 1. The loading and processing of a movie database with 600+ user ratings.
# 2. The creation of the NMF base model object
# 3. The creation of the database for the nbcfilter model
#
# Let's get started:

# %%
# Imports
from pathlib import Path
import os
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
from tqdm import tqdm
import dill as pickle
from sklearn.metrics.pairwise import cosine_similarity
import requests
#from ..scripts.config import OMDB_APIKEY as OMDB_APIKEY
OMDB_APIKEY = "A-very-cool-API-keys"

# %%
# Class and functions definitions

class ApiRequestLimitReached(Exception):
    """Custom exception to raise when request limit is reached"""

    pass

def get_movie_posters(movie_name: str, omdb_apikey: str = OMDB_APIKEY) -> str:
    """
    Returns the link to the movie poster.
    Note: Since cinemagoer aka former PyIMDB is extremely slow in handling requests, we go with https://www.omdbapi.com/
    Only 1000 request per day allowed: at some point the API will return Nones.
    """
    if (not "poster_links" in movies_information.columns) or (
        movies_information[movies_information.loc[:, "title"] == movie_name][
            "poster_links"
        ].values[0]
        == "http://www.interlog.com/~tfs/images/posters/TFSMoviePosterUnavailable.jpg"
    ):
        movie_id = movies_information[movies_information.loc[:, "title"] == movie_name][
            "imdbId"
        ].values[0]
        # We could also get the movie link directly (small image) with:
        # image = f"https://img.omdbapi.com/?apikey={omdb_apikey}&i=tt{movie_id:07}"
        # Get OMDB's JSON object of movie and get poster link from there (Amazon hosted and larger)
        # Note: with this many requests, our IP might be temp banned completely so that we don't receive
        # any response from the server. We should catch that error.
        try:
            get_json = requests.get(
                f"https://www.omdbapi.com/?apikey={omdb_apikey}&i=tt{movie_id:07}"
            ).json()
        except Exception as e:
            print("Get request failed: ", e)
            print(movie_name, ": left link as is because of API request error")
            return movies_information[movies_information.loc[:, "title"] == movie_name][
                "poster_links"
            ].values[0]
        # If we get a valid API response, process it
        if get_json["Response"] == "False":
            try:
                print(
                    movie_name,
                    ": left link as is b/c API returned False because: ",
                    get_json["Error"],
                )
            except:
                print(movie_name, ": left link as is b/c API returned False for reasons unknown")
            finally:
                raise ApiRequestLimitReached
        else:
            movie_poster_link = get_json.get("Poster")
            print(movie_name, ": added", movie_poster_link)
            return movie_poster_link
    else:
        print(movie_name, ": link already exists. Left as is.")
        return movies_information[movies_information.loc[:, "title"] == movie_name][
            "poster_links"
        ].values[0]


# Note the cosine similarity functions are not necessary thanks to sklearns cosine_similarity function
# This is just to demonstrate how you would do them manually.
def cosine_sim(vector_1, vector_2):
    """calculates cosine similarity between two vectors"""
    num = np.dot(vector_1, vector_2)
    denom = np.sqrt(np.dot(vector_1, vector_1)) * np.sqrt(np.dot(vector_2, vector_2))

    return num / denom


# Cosine table
def create_cosine_table(df):
    """Calculates the cosine similarity table (manually instead of using the sklearn method)"""
    data = []
    for user1 in tqdm(df.columns):
        row = []
        for user2 in df.columns:
            c = cosine_sim(df[user1], df[user2])
            row.append(c)
        data.append(row)
    cs = pd.DataFrame(data, index=df.columns, columns=df.columns).round(2)

    return cs

# %% [markdown]
# We first start with some very basic EDA to ensure our dataset is ready.
# The critical step here is to ensure that we get a dataset without any NaNs.

# %%
# Navigate out of subfolder
cwd = Path.cwd()
os.chdir(cwd.parent)

# Import datasets (start with the small one)
ratings = pd.read_csv(cwd.parent/ "datasets" / "ml-latest-small" / "ratings.csv")
movies = pd.read_csv(cwd.parent/  "datasets" / "ml-latest-small" / "movies.csv")

# Both dfs share a common key "movieId", let's merge on it:
merged_df = pd.merge(ratings, movies, on="movieId").sort_values(
    by=["userId", "movieId"], ascending=True
)

# %%
# Show some information about the dataset and clean checks
merged_df.info()
# Note: checking NaNs is very important because NMF (which we will use later) won't work with NaNs
print("Number of NaNs in the dataset: ", merged_df.rating.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 79014
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
#  4   title      100836 non-null  object
#  5   genres     100836 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.4+ MB
# Number of NaNs in the dataset:  0

# %% [markdown]
# The dataset is free of NaNs, so we do not need to impute anything yet. However, not each user has watched every movie, but for our modelling we still need a rating of some sort for each movie input. We therefore impute now:

# %%
# We can now pivot the merged_df by userId...
df = pd.pivot_table(merged_df, index="userId", columns="title", values="rating")
# ... and now fill in the blanks
# ... with either global mean:
# df = df.fillna(df.mean().mean())
# ... or per-item averages
# df = df.fillna(df.mean())
# ... or better: per-user averages
user_mean = df.mean(axis=1)
df = df.transpose().fillna(user_mean).transpose()
# ... or even better: per-user averages per genre (i.e. average user rating for genres).
# user_genre_mean = merged_df.groupby(["userId", "genres"])["rating"].mean()
# Note: if genre unrated, we use global per-user averages

# %% [markdown]
# At this point we are ready to create a dataframe that we can use to read general movie information out from. This is so that we can present it quickly to the user, without the need for an API request (which does require the API server to be up and our request limit not reached).
# Luckily, our dataset has all basic movie information so we only need to bring into the shape we want. However, it does not have links to the movie posters which we want to show to the user as well. These have to be fetched per API request to some movie database.
# Since we are using the free and publicly available OMDB (an IMDB-like movie database), we are restricted by 1000 API requests per day. To mitigate the OMDB restriction, we create the movie information dataframe once and store it after reaching out 1000 request limit. Reload it on another day, to use up our 1000 requests again, store it and so on.
#
# ##### Important: the code for storing the dataframe should only be run the very first time. Otherwise, we overwrite the already obtained movie poster links and have to start over.

# %%
df_links = pd.read_csv("datasets/ml-latest-small/links.csv")
movies_information = pd.merge(df_links, merged_df, on="movieId")
movies_information = movies_information.drop(
    ["userId", "movieId", "timestamp", "rating", "tmdbId"], axis=1
).drop_duplicates(subset=["imdbId"])
# Note there is certain movieIds that have the same title. Let's remove them because the user will work with movie titles:
movies_information = movies_information.drop_duplicates(subset=["title"])
# Average ratings per item
movies_information = pd.merge(
    movies_information, pd.Series(df.mean(), name="avg_ratings_pitem"), on="title"
)
# Transform genres and extract year and title into seperate columns
movies_information["genres"] = movies_information["genres"].str.split("|")
movies_information["year_only"] = movies_information["title"].str.extract(r"\((\d{4})\)")
movies_information["title_only"] = movies_information["title"].str.extract(r"(.*)\s*\(\d{4}\)")

# Run this part only the first time!
# # Get movie poster links
# movies_information["poster_links"] = movies_information["title"].apply(get_movie_posters)
# # For all posters, we haven't gotten (yet), insert a "Movie Poster Unavailable" placeholder.
# movies_information["poster_links"] = movies_information["poster_links"].fillna(
#     "http://www.interlog.com/~tfs/images/posters/TFSMoviePosterUnavailable.jpg"
# )
# # Store it sorted by title
# movies_information = movies_information.sort_values(by="title")
# with open("model_objects/movies_information" + ".pkl", "wb") as file:
#     pickle.dump(movies_information, file)

# %%
# Since we are limited by the API (1000 requests per day), we will have to call the function on separate
# days to update all movie poster links:
# Load to update
with open("model_objects/movies_information" + ".pkl", "rb") as file:
    movies_information = pickle.load(file)
# Note: while this is slower than using the apply function, we can abort request links from the API
# once we have reached the daily request limit:
try:
    for index, row in movies_information.iterrows():
        movies_information.at[index, "poster_links"] = get_movie_posters(row["title"])
except ApiRequestLimitReached:
    print("API Request limit reached! Aborting the update...")

# Store updated df
with open("model_objects/movies_information" + ".pkl", "wb") as file:
    pickle.dump(movies_information, file)
# Out:
# '71 (2014) : link already exists. Left as is.
# 'Hellboy': The Seeds of Creation (2004) : link already exists. Left as is.
# 'Round Midnight (1986) : link already exists. Left as is.
# 'Salem's Lot (2004) : link already exists. Left as is.
# 'Til There Was You (1997) : link already exists. Left as is.
# 'Tis the Season for Love (2015) : link already exists. Left as is.
# 'burbs, The (1989) : link already exists. Left as is.
# 'night Mother (1986) : link already exists. Left as is.
# (500) Days of Summer (2009) : link already exists. Left as is.
# *batteries not included (1987) : link already exists. Left as is.
# ...All the Marbles (1981) : link already exists. Left as is.
# ...And Justice for All (1979) : link already exists. Left as is.
# 00 Schneider - Jagd auf Nihil Baxter (1994) : link already exists. Left as is.
# 1-900 (06) (1994) : link already exists. Left as is.
# 10 (1979) : link already exists. Left as is.
# 10 Cent Pistol (2015) : link already exists. Left as is.
# 10 Cloverfield Lane (2016) : link already exists. Left as is.
# 10 Items or Less (2006) : link already exists. Left as is.
# 10 Things I Hate About You (1999) : link already exists. Left as is.
# 10 Years (2011) : link already exists. Left as is.
# 10,000 BC (2008) : link already exists. Left as is.
# 100 Girls (2000) : link already exists. Left as is.
# 100 Streets (2016) : link already exists. Left as is.
# 101 Dalmatians (1996) : link already exists. Left as is.
# 101 Dalmatians (One Hundred and One Dalmatians) (1961) : link already exists. Left as is.
# 101 Dalmatians II: Patch's London Adventure (2003) : link already exists. Left as is.
# 101 Reykjavik (101 Reykjavík) (2000) : link already exists. Left as is.
# 102 Dalmatians (2000) : link already exists. Left as is.
# 10th & Wolf (2006) : link already exists. Left as is.
# 10th Kingdom, The (2000) : link already exists. Left as is.
# 10th Victim, The (La decima vittima) (1965) : link already exists. Left as is.
# 11'09"01 - September 11 (2002) : link already exists. Left as is.
# 11:14 (2003) : link already exists. Left as is.
# 11th Hour, The (2007) : link already exists. Left as is.
# 12 Angry Men (1957) : link already exists. Left as is.
# 12 Angry Men (1997) : link already exists. Left as is.
# 12 Chairs (1971) : link already exists. Left as is.
# 12 Chairs (1976) : link already exists. Left as is.
# 12 Rounds (2009) : link already exists. Left as is.
# 12 Years a Slave (2013) : link already exists. Left as is.
# 127 Hours (2010) : link already exists. Left as is.
# 13 Assassins (Jûsan-nin no shikaku) (2010) : link already exists. Left as is.
# 13 Ghosts (1960) : link already exists. Left as is.
# 13 Going on 30 (2004) : link already exists. Left as is.
# 13 Hours (2016) : link already exists. Left as is.
# 13 Sins (2014) : link already exists. Left as is.
# 13 Tzameti (2005) : link already exists. Left as is.
# 13th (2016) : link already exists. Left as is.
# 13th Warrior, The (1999) : link already exists. Left as is.
# 1408 (2007) : link already exists. Left as is.
# 1492: Conquest of Paradise (1992) : link already exists. Left as is.
# 15 Minutes (2001) : link already exists. Left as is.
# 16 Blocks (2006) : link already exists. Left as is.
# 17 Again (2009) : link already exists. Left as is.
# 1776 (1972) : link already exists. Left as is.
# 18 Again! (1988) : link already exists. Left as is.
# 187 (One Eight Seven) (1997) : link already exists. Left as is.
# 1900 (Novecento) (1976) : link already exists. Left as is.
# 1941 (1979) : link already exists. Left as is.
# 1969 (1988) : link already exists. Left as is.
# 1984 (Nineteen Eighty-Four) (1984) : link already exists. Left as is.
# 2 Days in New York (2012) : link already exists. Left as is.
# 2 Days in Paris (2007) : link already exists. Left as is.
# 2 Days in the Valley (1996) : link already exists. Left as is.
# 2 Fast 2 Furious (Fast and the Furious 2, The) (2003) : link already exists. Left as is.
# 2 Guns (2013) : link already exists. Left as is.
# 20 Dates (1998) : link already exists. Left as is.
# 20 Feet from Stardom (Twenty Feet from Stardom) (2013) : link already exists. Left as is.
# 20 Million Miles to Earth (1957) : link already exists. Left as is.
# 20,000 Days on Earth (2014) : link already exists. Left as is.
# 20,000 Leagues Under the Sea (1916) : link already exists. Left as is.
# 20,000 Leagues Under the Sea (1954) : link already exists. Left as is.
# 200 Cigarettes (1999) : link already exists. Left as is.
# 2001 Maniacs (2005) : link already exists. Left as is.
# 2001: A Space Odyssey (1968) : link already exists. Left as is.
# 2010: The Year We Make Contact (1984) : link already exists. Left as is.
# 2012 (2009) : link already exists. Left as is.
# 2046 (2004) : link already exists. Left as is.
# 2048: Nowhere to Run (2017) : link already exists. Left as is.
# 21 (2008) : link already exists. Left as is.
# 21 Grams (2003) : link already exists. Left as is.
# 21 Jump Street (2012) : link already exists. Left as is.
# 21 Up (1977) : link already exists. Left as is.
# 21 and Over (2013) : link already exists. Left as is.
# 22 Jump Street (2014) : link already exists. Left as is.
# 24 Hour Party People (2002) : link already exists. Left as is.
# 25th Hour (2002) : link already exists. Left as is.
# 27 Dresses (2008) : link already exists. Left as is.
# 28 Days (2000) : link already exists. Left as is.
# 28 Days Later (2002) : link already exists. Left as is.
# 28 Up (1985) : link already exists. Left as is.
# 28 Weeks Later (2007) : link already exists. Left as is.
# 3 Days to Kill (2014) : link already exists. Left as is.
# 3 Extremes (Three... Extremes) (Saam gaang yi) (2004) : link already exists. Left as is.
# 3 Idiots (2009) : link already exists. Left as is.
# 3 Ninjas (1992) : link already exists. Left as is.
# 3 Ninjas Kick Back (1994) : link already exists. Left as is.
# 3 Ninjas Knuckle Up (1995) : link already exists. Left as is.
# 3 Ninjas: High Noon On Mega Mountain (1998) : link already exists. Left as is.
# 3 Women (Three Women) (1977) : link already exists. Left as is.
# 3 dev adam (Three Giant Men) (1973)  : link already exists. Left as is.
# 3-Iron (Bin-jip) (2004) : link already exists. Left as is.
# 30 Days of Night (2007) : link already exists. Left as is.
# 30 Minutes or Less (2011) : link already exists. Left as is.
# 300 (2007) : link already exists. Left as is.
# 3000 Miles to Graceland (2001) : link already exists. Left as is.
# 300: Rise of an Empire (2014) : link already exists. Left as is.
# 31 (2016) : link already exists. Left as is.
# 35 Up (1991) : link already exists. Left as is.
# 39 Steps, The (1935) : link already exists. Left as is.
# 3:10 to Yuma (1957) : link already exists. Left as is.
# 3:10 to Yuma (2007) : link already exists. Left as is.
# 4 Little Girls (1997) : link already exists. Left as is.
# 4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile) (2007) : link already exists. Left as is.
# 40 Days and 40 Nights (2002) : link already exists. Left as is.
# 40-Year-Old Virgin, The (2005) : link already exists. Left as is.
# 400 Blows, The (Les quatre cents coups) (1959) : link already exists. Left as is.
# 42 (2013) : link already exists. Left as is.
# 42 Up (1998) : link already exists. Left as is.
# 42nd Street (1933) : link already exists. Left as is.
# 47 Ronin (2013) : link already exists. Left as is.
# 48 Hrs. (1982) : link already exists. Left as is.
# 49 Up (2005) : link already exists. Left as is.
# 5 Centimeters per Second (Byôsoku 5 senchimêtoru) (2007) : link already exists. Left as is.
# 5 to 7 (2014) : link already exists. Left as is.
# 5,000 Fingers of Dr. T, The (1953) : link already exists. Left as is.
# 50 First Dates (2004) : link already exists. Left as is.
# 50/50 (2011) : link already exists. Left as is.
# 52 Pick-Up (1986) : link already exists. Left as is.
# 54 (1998) : link already exists. Left as is.
# 6 Days to Air: The Making of South Park (2011) : link already exists. Left as is.
# 61* (2001) : link already exists. Left as is.
# 6th Day, The (2000) : link already exists. Left as is.
# 6th Man, The (Sixth Man, The) (1997) : link already exists. Left as is.
# 7 Days in Hell (2015) : link already exists. Left as is.
# 7 Faces of Dr. Lao (1964) : link already exists. Left as is.
# 7th Voyage of Sinbad, The (1958) : link already exists. Left as is.
# 8 1/2 (8½) (1963) : link already exists. Left as is.
# 8 Heads in a Duffel Bag (1997) : link already exists. Left as is.
# 8 Mile (2002) : link already exists. Left as is.
# 8 Seconds (1994) : link already exists. Left as is.
# 8 Women (2002) : link already exists. Left as is.
# 8 ½ Women (a.k.a. 8 1/2 Women) (a.k.a. Eight and a Half Women) (1999) : link already exists. Left as is.
# 800 Bullets (800 Balas) (2002) : link already exists. Left as is.
# 84 Charing Cross Road (1987) : link already exists. Left as is.
# 8MM (1999) : link already exists. Left as is.
# 9 (2009) : link already exists. Left as is.
# 9 1/2 Weeks (Nine 1/2 Weeks) (1986) : link already exists. Left as is.
# 9/11 (2002) : link already exists. Left as is.
# 96 Minutes (2011)  : link already exists. Left as is.
# 964 Pinocchio (1991) : link already exists. Left as is.
# 99 francs (2007) : link already exists. Left as is.
# 9to5: Days in Porn (a.k.a. 9 to 5: Days in Porn) (2008) : link already exists. Left as is.
# A Bad Moms Christmas (2017) : link already exists. Left as is.
# A Christmas Story Live! (2017) : link already exists. Left as is.
# A Cosmic Christmas (1977) : link already exists. Left as is.
# A Detective Story (2003) : link already exists. Left as is.
# A Dog's Purpose (2017) : link already exists. Left as is.
# A Flintstones Christmas Carol (1994) : link already exists. Left as is.
# A German Life (2016) : link already exists. Left as is.
# A Home at the End of the World (2004) : link already exists. Left as is.
# A Man Called Blade (1977) : link already exists. Left as is.
# A Man from Boulevard des Capucines (1987) : link already exists. Left as is.
# A Merry Friggin' Christmas (2014) : link already exists. Left as is.
# A Midsummer Night's Dream (2016) : link already exists. Left as is.
# A Million Ways to Die in the West (2014) : link already exists. Left as is.
# A Most Wanted Man (2014) : link already exists. Left as is.
# A Perfect Day (2015) : link already exists. Left as is.
# A Pigeon Sat on a Branch Reflecting on Existence (2014) : link already exists. Left as is.
# A Plasticine Crow (1981) : link already exists. Left as is.
# A Quiet Place (2018) : link already exists. Left as is.
# A Silent Voice (2016) : link already exists. Left as is.
# A Story of Children and Film (2013) : link already exists. Left as is.
# A Street Cat Named Bob (2016) : link already exists. Left as is.
# A Very Murray Christmas (2015) : link already exists. Left as is.
# A Walk in the Woods (2015) : link already exists. Left as is.
# A Wrinkle in Time (2018) : link already exists. Left as is.
# A-Team, The (2010) : link already exists. Left as is.
# A.I. Artificial Intelligence (2001) : link already exists. Left as is.
# ABCs of Death, The (2012) : link already exists. Left as is.
# ARQ (2016) : link already exists. Left as is.
# AVP: Alien vs. Predator (2004) : link already exists. Left as is.
# AVPR: Aliens vs. Predator - Requiem (2007) : link already exists. Left as is.
# Abandoned, The (2006) : link already exists. Left as is.
# Abbott and Costello Meet Frankenstein (1948) : link already exists. Left as is.
# Abduction (2011) : link already exists. Left as is.
# Abominable Dr. Phibes, The (1971) : link already exists. Left as is.
# Abominable Snowman, The (Abominable Snowman of the Himalayas, The) (1957) : link already exists. Left as is.
# About Adam (2000) : link already exists. Left as is.
# About Last Night (2014) : link already exists. Left as is.
# About Last Night... (1986) : link already exists. Left as is.
# About Schmidt (2002) : link already exists. Left as is.
# About Time (2013) : link already exists. Left as is.
# About a Boy (2002) : link already exists. Left as is.
# Above the Law (1988) : link already exists. Left as is.
# Above the Rim (1994) : link already exists. Left as is.
# Abraham Lincoln: Vampire Hunter (2012) : link already exists. Left as is.
# Absence of Malice (1981) : link already exists. Left as is.
# Absent-Minded Professor, The (1961) : link already exists. Left as is.
# Absentia (2011) : link already exists. Left as is.
# Absolute Power (1997) : link already exists. Left as is.
# Absolutely Anything (2015) : link already exists. Left as is.
# Abyss, The (1989) : link already exists. Left as is.
# Accepted (2006) : link already exists. Left as is.
# Accidental Spy, The (Dak miu mai shing) (2001) : link already exists. Left as is.
# Accidental Tourist, The (1988) : link already exists. Left as is.
# Accused, The (1988) : link already exists. Left as is.
# Ace Ventura: Pet Detective (1994) : link already exists. Left as is.
# Ace Ventura: When Nature Calls (1995) : link already exists. Left as is.
# Ace in the Hole (Big Carnival, The) (1951) : link already exists. Left as is.
# Aces: Iron Eagle III (1992) : link already exists. Left as is.
# Acid House, The (1998) : link already exists. Left as is.
# Across the Hall (2009) : link already exists. Left as is.
# Across the Universe (2007) : link already exists. Left as is.
# Act of Killing, The (2012) : link already exists. Left as is.
# Act of Valor (2012) : link already exists. Left as is.
# Action Jackson (1988) : link already exists. Left as is.
# Adam and Eve (National Lampoon's Adam & Eve) (2005) : link already exists. Left as is.
# Adam's Apples (Adams æbler) (2005) : link already exists. Left as is.
# Adam's Rib (1949) : link already exists. Left as is.
# Adanggaman (2000) : link already exists. Left as is.
# Adaptation (2002) : link already exists. Left as is.
# Addams Family Reunion (1998) : link already exists. Left as is.
# Addams Family Values (1993) : link already exists. Left as is.
# Addams Family, The (1991) : link already exists. Left as is.
# Addicted to Love (1997) : link already exists. Left as is.
# Addiction, The (1995) : link already exists. Left as is.
# Adjustment Bureau, The (2011) : link already exists. Left as is.
# Admission (2013) : link already exists. Left as is.
# Adventureland (2009) : link already exists. Left as is.
# Adventures Of Sherlock Holmes And Dr. Watson: The Twentieth Century Approaches (1986) : link already exists. Left as is.
# Adventures in Babysitting (1987) : link already exists. Left as is.
# Adventures in Plymptoons! (2011) : link already exists. Left as is.
# Adventures of Baron Munchausen, The (1988) : link already exists. Left as is.
# Adventures of Buckaroo Banzai Across the 8th Dimension, The (1984) : link already exists. Left as is.
# Adventures of Elmo in Grouchland, The (1999) : link already exists. Left as is.
# Adventures of Ford Fairlane, The (1990) : link already exists. Left as is.
# Adventures of Huck Finn, The (1993) : link already exists. Left as is.
# Adventures of Ichabod and Mr. Toad, The (1949) : link already exists. Left as is.
# Adventures of Mary-Kate and Ashley, The: The Case of the Christmas Caper (1995) : link already exists. Left as is.
# Adventures of Milo and Otis, The (Koneko monogatari) (1986) : link already exists. Left as is.
# Adventures of Mowgli: The Kidnapping (1968) : link already exists. Left as is.
# Adventures of Pinocchio, The (1996) : link already exists. Left as is.
# Adventures of Pluto Nash, The (2002) : link already exists. Left as is.
# Adventures of Priscilla, Queen of the Desert, The (1994) : link already exists. Left as is.
# Adventures of Robin Hood, The (1938) : link already exists. Left as is.
# Adventures of Rocky and Bullwinkle, The (2000) : link already exists. Left as is.
# Adventures of Sebastian Cole, The (1998) : link already exists. Left as is.
# Adventures of Sharkboy and Lavagirl 3-D, The (2005) : link already exists. Left as is.
# Adventures of Tintin, The (2011) : link already exists. Left as is.
# Advise and Consent (1962) : link already exists. Left as is.
# Aelita: The Queen of Mars (Aelita) (1924) : link already exists. Left as is.
# Aeon Flux (2005) : link already exists. Left as is.
# Affair of Love, An (Liaison pornographique, Une) (1999) : link already exists. Left as is.
# Affair of the Necklace, The (2001) : link already exists. Left as is.
# Affair to Remember, An (1957) : link already exists. Left as is.
# Afflicted (2013) : link already exists. Left as is.
# Affliction (1997) : link already exists. Left as is.
# Afonya (1975) : link already exists. Left as is.
# Africa: The Serengeti (1994) : link already exists. Left as is.
# African Cats (2011) : link already exists. Left as is.
# African Queen, The (1951) : link already exists. Left as is.
# Afro Samurai (2007) : link already exists. Left as is.
# Afro Samurai: Resurrection (2009) : link already exists. Left as is.
# After Earth (2013) : link already exists. Left as is.
# After Hours (1985) : link already exists. Left as is.
# After Life (Wandafuru raifu) (1998) : link already exists. Left as is.
# After the Fox (Caccia alla volpe) (1966) : link already exists. Left as is.
# After the Sunset (2004) : link already exists. Left as is.
# After the Thin Man (1936) : link already exists. Left as is.
# After the Wedding (Efter brylluppet) (2006) : link already exists. Left as is.
# Afterglow (1997) : link already exists. Left as is.
# Against All Odds (1984) : link already exists. Left as is.
# Against the Ropes (2004) : link already exists. Left as is.
# Age of Innocence, The (1993) : link already exists. Left as is.
# Agent Cody Banks (2003) : link already exists. Left as is.
# Agent Cody Banks 2: Destination London (2004) : link already exists. Left as is.
# Agnes of God (1985) : link already exists. Left as is.
# Agony and the Ecstasy, The (1965) : link already exists. Left as is.
# Agora (2009) : link already exists. Left as is.
# Aguirre: The Wrath of God (Aguirre, der Zorn Gottes) (1972) : link already exists. Left as is.
# Aileen: Life and Death of a Serial Killer (2003) : link already exists. Left as is.
# Air America (1990) : link already exists. Left as is.
# Air Bud (1997) : link already exists. Left as is.
# Air Bud: Golden Receiver (1998) : link already exists. Left as is.
# Air Force One (1997) : link already exists. Left as is.
# Air I Breathe, The (2007) : link already exists. Left as is.
# Air Up There, The (1994) : link already exists. Left as is.
# Airborne (1993) : link already exists. Left as is.
# Airheads (1994) : link already exists. Left as is.
# Airplane II: The Sequel (1982) : link already exists. Left as is.
# Airplane! (1980) : link already exists. Left as is.
# Airport '77 (1977) : link already exists. Left as is.
# Airport (1970) : link already exists. Left as is.
# Airport 1975 (1974) : link already exists. Left as is.
# Akeelah and the Bee (2006) : link already exists. Left as is.
# Akira (1988) : link already exists. Left as is.
# Akira Kurosawa's Dreams (Dreams) (1990) : link already exists. Left as is.
# Aladdin (1992) : link already exists. Left as is.
# Aladdin and the King of Thieves (1996) : link already exists. Left as is.
# Alamo, The (1960) : link already exists. Left as is.
# Alan Partridge: Alpha Papa (2013) : link already exists. Left as is.
# Alaska (1996) : link already exists. Left as is.
# Alaska: Spirit of the Wild (1997) : link already exists. Left as is.
# Albatross (2011) : link already exists. Left as is.
# Albino Alligator (1996) : link already exists. Left as is.
# Alesha Popovich and Tugarin the Dragon (2004) : link already exists. Left as is.
# Alex Cross (2012) : link already exists. Left as is.
# Alex and Emma (2003) : link already exists. Left as is.
# Alexander (2004) : link already exists. Left as is.
# Alexander Nevsky (Aleksandr Nevskiy) (1938) : link already exists. Left as is.
# Alfie (1966) : link already exists. Left as is.
# Alfie (2004) : link already exists. Left as is.
# Ali (2001) : link already exists. Left as is.
# Ali G Indahouse (2002) : link already exists. Left as is.
# Ali Wong: Baby Cobra (2016) : link already exists. Left as is.
# Ali: Fear Eats the Soul (Angst essen Seele auf) (1974) : link already exists. Left as is.
# Alias Betty (Betty Fisher et autres histoires) (2001) : link already exists. Left as is.
# Alice (1990) : link already exists. Left as is.
# Alice (2009) : link already exists. Left as is.
# Alice (Neco z Alenky) (1988) : link already exists. Left as is.
# Alice Adams (1935) : link already exists. Left as is.
# Alice Doesn't Live Here Anymore (1974) : link already exists. Left as is.
# Alice Through the Looking Glass (2016) : link already exists. Left as is.
# Alice in Wonderland (1933) : link already exists. Left as is.
# Alice in Wonderland (1951) : link already exists. Left as is.
# Alice in Wonderland (2010) : link already exists. Left as is.
# Alien (1979) : link already exists. Left as is.
# Alien Contamination (1980) : link already exists. Left as is.
# Alien Nation (1988) : link already exists. Left as is.
# Alien from L.A. (1988) : link already exists. Left as is.
# Alien: Covenant (2017) : link already exists. Left as is.
# Alien: Resurrection (1997) : link already exists. Left as is.
# Aliens (1986) : link already exists. Left as is.
# Alien³ (a.k.a. Alien 3) (1992) : link already exists. Left as is.
# Alive (1993) : link already exists. Left as is.
# All About Eve (1950) : link already exists. Left as is.
# All About Lily Chou-Chou (Riri Shushu no subete) (2001) : link already exists. Left as is.
# All About My Mother (Todo sobre mi madre) (1999) : link already exists. Left as is.
# All About the Benjamins (2002) : link already exists. Left as is.
# All Dogs Christmas Carol, An (1998) : link already exists. Left as is.
# All Dogs Go to Heaven (1989) : link already exists. Left as is.
# All Dogs Go to Heaven 2 (1996) : link already exists. Left as is.
# All Good Things (2010) : link already exists. Left as is.
# All Is Lost (2013) : link already exists. Left as is.
# All Over the Guy (2001) : link already exists. Left as is.
# All Quiet on the Western Front (1930) : link already exists. Left as is.
# All Roads Lead to Rome (2016) : link already exists. Left as is.
# All That Heaven Allows (1955) : link already exists. Left as is.
# All That Jazz (1979) : link already exists. Left as is.
# All This, and Heaven Too (1940) : link already exists. Left as is.
# All Watched Over by Machines of Loving Grace (2011) : link already exists. Left as is.
# All Yours (2016) : link already exists. Left as is.
# All is Bright (2013) : link already exists. Left as is.
# All of Me (1984) : link already exists. Left as is.
# All or Nothing (2002) : link already exists. Left as is.
# All the Boys Love Mandy Lane (2006) : link already exists. Left as is.
# All the King's Men (1949) : link already exists. Left as is.
# All the King's Men (2006) : link already exists. Left as is.
# All the President's Men (1976) : link already exists. Left as is.
# All the Pretty Horses (2000) : link already exists. Left as is.
# All the Real Girls (2003) : link already exists. Left as is.
# All the Right Moves (1983) : link already exists. Left as is.
# All the Vermeers in New York (1990) : link already exists. Left as is.
# All-Star Superman (2011) : link already exists. Left as is.
# Allan Quatermain and the Lost City of Gold (1987) : link already exists. Left as is.
# Allegro non troppo (1977) : link already exists. Left as is.
# Alles Inklusive (2014) : link already exists. Left as is.
# Alligator (1980) : link already exists. Left as is.
# Allnighter, The (1987) : link already exists. Left as is.
# Almost Famous (2000) : link already exists. Left as is.
# Almost Heroes (1998) : link already exists. Left as is.
# Almost an Angel (1990) : link already exists. Left as is.
# Aloha (2015) : link already exists. Left as is.
# Alone in the Dark (2005) : link already exists. Left as is.
# Alone in the Dark II (2008) : link already exists. Left as is.
# Along Came Polly (2004) : link already exists. Left as is.
# Along Came a Spider (2001) : link already exists. Left as is.
# Alpha (2018) : link already exists. Left as is.
# Alpha Dog (2007) : link already exists. Left as is.
# Alpha and Omega 3: The Great Wolf Games (2014) : link already exists. Left as is.
# Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965) : link already exists. Left as is.
# Altered (2006) : link already exists. Left as is.
# Altered States (1980) : link already exists. Left as is.
# Alvarez Kelly (1966) : link already exists. Left as is.
# Alvin and the Chipmunks (2007) : link already exists. Left as is.
# Alvin and the Chipmunks: Chipwrecked (2011) : link already exists. Left as is.
# Alvin and the Chipmunks: The Squeakquel (2009) : link already exists. Left as is.
# Always (1989) : link already exists. Left as is.
# Always Watching: A Marble Hornets Story (2015) : link already exists. Left as is.
# Amadeus (1984) : link already exists. Left as is.
# Amanda Knox (2016) : link already exists. Left as is.
# Amarcord (1973) : link already exists. Left as is.
# Amateur (1994) : link already exists. Left as is.
# Amazing Grace (2006) : link already exists. Left as is.
# Amazing Grace and Chuck (1987) : link already exists. Left as is.
# Amazing Panda Adventure, The (1995) : link already exists. Left as is.
# Amazing Spider-Man, The (2012) : link already exists. Left as is.
# Amazing Transparent Man, The (1960) : link already exists. Left as is.
# Amazon Women on the Moon (1987) : link already exists. Left as is.
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001) : link already exists. Left as is.
# Amen. (2002) : link already exists. Left as is.
# Amer (2009) : link already exists. Left as is.
# America's Sweethearts (2001) : link already exists. Left as is.
# American Astronaut, The (2001) : link already exists. Left as is.
# American Beauty (1999) : link already exists. Left as is.
# American Buffalo (1996) : link already exists. Left as is.
# American Carol, An (2008) : link already exists. Left as is.
# American Dreamz (2006) : link already exists. Left as is.
# American Drug War: The Last White Hope (2007) : link already exists. Left as is.
# American Fable (2017) : link already exists. Left as is.
# American Flyers (1985) : link already exists. Left as is.
# American Friend, The (Amerikanische Freund, Der) (1977) : link already exists. Left as is.
# American Gangster (2007) : link already exists. Left as is.
# American Gigolo (1980) : link already exists. Left as is.
# American Graffiti (1973) : link already exists. Left as is.
# American Grindhouse (2010) : link already exists. Left as is.
# American Hardcore (2006) : link already exists. Left as is.
# American Haunting, An (2005) : link already exists. Left as is.
# American Heist (2015) : link already exists. Left as is.
# American History X (1998) : link already exists. Left as is.
# American Hustle (2013) : link already exists. Left as is.
# American Made (2017) : link already exists. Left as is.
# American Me (1992) : link already exists. Left as is.
# American Movie (1999) : link already exists. Left as is.
# American Ninja (1985) : link already exists. Left as is.
# American Outlaws (2001) : link already exists. Left as is.
# American Pie (1999) : link already exists. Left as is.
# American Pie 2 (2001) : link already exists. Left as is.
# American Pie Presents Beta House (American Pie 6: Beta House) (2007) : link already exists. Left as is.
# American Pie Presents The Naked Mile (American Pie 5: The Naked Mile) (2006) : link already exists. Left as is.
# American Pie Presents: Band Camp (American Pie 4: Band Camp) (2005) : link already exists. Left as is.
# American Pie Presents: The Book of Love (American Pie 7: The Book of Love) (2009) : link already exists. Left as is.
# American Pop (1981) : link already exists. Left as is.
# American President, The (1995) : link already exists. Left as is.
# American Psycho (2000) : link already exists. Left as is.
# American Psycho II: All American Girl (2002) : link already exists. Left as is.
# American Reunion (American Pie 4) (2012) : link already exists. Left as is.
# American Sniper (2014) : link already exists. Left as is.
# American Splendor (2003) : link already exists. Left as is.
# American Tail, An (1986) : link already exists. Left as is.
# American Tail: Fievel Goes West, An (1991) : link already exists. Left as is.
# American Ultra (2015) : link already exists. Left as is.
# American Wedding (American Pie 3) (2003) : link already exists. Left as is.
# American Werewolf in London, An (1981) : link already exists. Left as is.
# American Werewolf in Paris, An (1997) : link already exists. Left as is.
# American in Paris, An (1951) : link already exists. Left as is.
# American, The (2010) : link already exists. Left as is.
# American: The Bill Hicks Story (2009) : link already exists. Left as is.
# Americanization of Emily, The (1964) : link already exists. Left as is.
# Americathon (1979) : link already exists. Left as is.
# Amistad (1997) : link already exists. Left as is.
# Amityville 1992: It's About Time (1992) : link already exists. Left as is.
# Amityville 3-D (1983) : link already exists. Left as is.
# Amityville Curse, The (1990) : link already exists. Left as is.
# Amityville Horror, The (1979) : link already exists. Left as is.
# Amityville Horror, The (2005) : link already exists. Left as is.
# Amityville II: The Possession (1982) : link already exists. Left as is.
# Amityville: A New Generation (1993) : link already exists. Left as is.
# Amityville: Dollhouse (1996) : link already exists. Left as is.
# Amores Perros (Love's a Bitch) (2000) : link already exists. Left as is.
# Amos & Andrew (1993) : link already exists. Left as is.
# Amy (2015) : link already exists. Left as is.
# Amy's O (a.k.a. Amy's Orgasm) (2001) : link already exists. Left as is.
# An Amazing Couple (2002) : link already exists. Left as is.
# Anacleto: Agente secreto (2015) : link already exists. Left as is.
# Anaconda (1997) : link already exists. Left as is.
# Anaconda: The Offspring (2008) : link already exists. Left as is.
# Anacondas: The Hunt for the Blood Orchid (2004) : link already exists. Left as is.
# Analyze That (2002) : link already exists. Left as is.
# Analyze This (1999) : link already exists. Left as is.
# Anarchist Cookbook, The (2002) : link already exists. Left as is.
# Anastasia (1956) : link already exists. Left as is.
# Anastasia (1997) : link already exists. Left as is.
# Anatomy of a Murder (1959) : link already exists. Left as is.
# Anchorman 2: The Legend Continues (2013) : link already exists. Left as is.
# Anchorman: The Legend of Ron Burgundy (2004) : link already exists. Left as is.
# Anchors Aweigh (1945) : link already exists. Left as is.
# And God Created Woman (Et Dieu... créa la femme) (1956) : link already exists. Left as is.
# And Now... Ladies and Gentlemen... (2002) : link already exists. Left as is.
# And So It Goes (2014) : link already exists. Left as is.
# And Starring Pancho Villa as Himself (2003) : link already exists. Left as is.
# And Then There Were None (1945) : link already exists. Left as is.
# And Your Mother Too (Y tu mamá también) (2001) : link already exists. Left as is.
# And the Band Played On (1993) : link already exists. Left as is.
# And the Ship Sails On (E la nave va) (1983) : link already exists. Left as is.
# Andalusian Dog, An (Chien andalou, Un) (1929) : link already exists. Left as is.
# Andre (1994) : link already exists. Left as is.
# Andrei Rublev (Andrey Rublyov) (1969) : link already exists. Left as is.
# Andrew Dice Clay: Dice Rules (1991) : link already exists. Left as is.
# Android (1982) : link already exists. Left as is.
# Andromeda Strain, The (1971) : link already exists. Left as is.
# Angel Baby (1995) : link already exists. Left as is.
# Angel Eyes (2001) : link already exists. Left as is.
# Angel Heart (1987) : link already exists. Left as is.
# Angel at My Table, An (1990) : link already exists. Left as is.
# Angel's Egg (Tenshi no tamago) (1985) : link already exists. Left as is.
# Angel-A (2005) : link already exists. Left as is.
# Angela's Ashes (1999) : link already exists. Left as is.
# Angels & Demons (2009) : link already exists. Left as is.
# Angels and Insects (1995) : link already exists. Left as is.
# Angels in the Outfield (1994) : link already exists. Left as is.
# Angels with Dirty Faces (1938) : link already exists. Left as is.
# Angels' Share, The (2012) : link already exists. Left as is.
# Anger Management (2003) : link already exists. Left as is.
# Angie (1994) : link already exists. Left as is.
# Angriest Man in Brooklyn, The (2014) : link already exists. Left as is.
# Angry Red Planet, The (1959) : link already exists. Left as is.
# Angst  (1983) : link already exists. Left as is.
# Angus (1995) : link already exists. Left as is.
# Angus, Thongs and Perfect Snogging (2008) : link already exists. Left as is.
# Animal Crackers (1930) : link already exists. Left as is.
# Animal Factory (2000) : link already exists. Left as is.
# Animal Farm (1954) : link already exists. Left as is.
# Animal House (1978) : link already exists. Left as is.
# Animal, The (2001) : link already exists. Left as is.
# Animals are Beautiful People (1974) : link already exists. Left as is.
# Animatrix, The (2003) : link already exists. Left as is.
# Anna Christie (1930) : link already exists. Left as is.
# Anna Karenina (1935) : link already exists. Left as is.
# Anna Karenina (1997) : link already exists. Left as is.
# Anna Karenina (2012) : link already exists. Left as is.
# Anna and the King (1999) : link already exists. Left as is.
# Annabelle (2014) : link already exists. Left as is.
# Annabelle: Creation (2017) : link already exists. Left as is.
# Annapolis (2006) : link already exists. Left as is.
# Anne Frank Remembered (1995) : link already exists. Left as is.
# Anne of Green Gables (1985) : link already exists. Left as is.
# Anne of Green Gables: The Sequel (a.k.a. Anne of Avonlea) (1987) : link already exists. Left as is.
# Anne of the Thousand Days (1969) : link already exists. Left as is.
# Annie (1982) : link already exists. Left as is.
# Annie Get Your Gun (1950) : link already exists. Left as is.
# Annie Hall (1977) : link already exists. Left as is.
# Annihilation (2018) : link already exists. Left as is.
# Anniversary Party, The (2001) : link already exists. Left as is.
# Anomalisa (2015) : link already exists. Left as is.
# Another 48 Hrs. (1990) : link already exists. Left as is.
# Another Cinderella Story (2008) : link already exists. Left as is.
# Another Earth (2011) : link already exists. Left as is.
# Another Gay Movie (2006) : link already exists. Left as is.
# Another Stakeout (1993) : link already exists. Left as is.
# Another Thin Man (1939) : link already exists. Left as is.
# Another Woman (1988) : link already exists. Left as is.
# Ant Bully, The (2006) : link already exists. Left as is.
# Ant-Man (2015) : link already exists. Left as is.
# Ant-Man and the Wasp (2018) : link already exists. Left as is.
# Anthony Adverse (1936) : link already exists. Left as is.
# Anti-Social (2015) : link already exists. Left as is.
# Antichrist (2009) : link already exists. Left as is.
# Antitrust (2001) : link already exists. Left as is.
# Antonia's Line (Antonia) (1995) : link already exists. Left as is.
# Antonio Gaudí (1985) : link already exists. Left as is.
# Antwone Fisher (2002) : link already exists. Left as is.
# Antz (1998) : link already exists. Left as is.
# Anvil! The Story of Anvil (2008) : link already exists. Left as is.
# Any Given Sunday (1999) : link already exists. Left as is.
# Any Which Way You Can (1980) : link already exists. Left as is.
# Anything Else (2003) : link already exists. Left as is.
# Anything for Her (Pour elle) (2008) : link already exists. Left as is.
# Anything for Love (2016) : link already exists. Left as is.
# Anywhere But Here (1999) : link already exists. Left as is.
# Apartment, The (1960) : link already exists. Left as is.
# Apartment, The (Appartement, L') (1996) : link already exists. Left as is.
# Apocalypse Now (1979) : link already exists. Left as is.
# Apocalypto (2006) : link already exists. Left as is.
# Apollo 13 (1995) : link already exists. Left as is.
# Apollo 18 (2011) : link already exists. Left as is.
# Apostle, The (1997) : link already exists. Left as is.
# Appaloosa (2008) : link already exists. Left as is.
# Apple Dumpling Gang Rides Again, The (1979) : link already exists. Left as is.
# Apple Dumpling Gang, The (1975) : link already exists. Left as is.
# Apple, The (Sib) (1998) : link already exists. Left as is.
# Applesauce (2015) : link already exists. Left as is.
# Appleseed (Appurushîdo) (2004) : link already exists. Left as is.
# April Fool's Day (1986) : link already exists. Left as is.
# April Morning (1988) : link already exists. Left as is.
# Apt Pupil (1998) : link already exists. Left as is.
# Aqua Teen Hunger Force Colon Movie Film for Theaters (2007) : link already exists. Left as is.
# Aquamarine (2006) : link already exists. Left as is.
# Arachnophobia (1990) : link already exists. Left as is.
# Ararat (2002) : link already exists. Left as is.
# Are We Done Yet? (2007) : link already exists. Left as is.
# Are We There Yet? (2005) : link already exists. Left as is.
# Are You Scared? (2006) : link already exists. Left as is.
# Argo (2012) : link already exists. Left as is.
# Ari Shaffir: Double Negative (2017) : link already exists. Left as is.
# Ariel (1988) : link already exists. Left as is.
# Aristocats, The (1970) : link already exists. Left as is.
# Aristocrats, The (2005) : link already exists. Left as is.
# Arizona Dream (1993) : link already exists. Left as is.
# Arlington Road (1999) : link already exists. Left as is.
# Armageddon (1998) : link already exists. Left as is.
# Armed and Dangerous (1986) : link already exists. Left as is.
# Armour of God (Long xiong hu di) (1987) : link already exists. Left as is.
# Armour of God II: Operation Condor (Operation Condor) (Fei ying gai wak) (1991) : link already exists. Left as is.
# Army of Darkness (1993) : link already exists. Left as is.
# Army of Shadows (L'armée des ombres) (1969) : link already exists. Left as is.
# Around the World in 80 Days (1956) : link already exists. Left as is.
# Around the World in 80 Days (2004) : link already exists. Left as is.
# Arrival (2016) : link already exists. Left as is.
# Arrival, The (1996) : link already exists. Left as is.
# Arsenic and Old Lace (1944) : link already exists. Left as is.
# Art School Confidential (2006) : link already exists. Left as is.
# Art of Getting By, The (2011) : link already exists. Left as is.
# Art of War, The (2000) : link already exists. Left as is.
# Art of the Steal, The (2009) : link already exists. Left as is.
# Art of the Steal, The (2013) : link already exists. Left as is.
# Artemisia (1997) : link already exists. Left as is.
# Arthur (1981) : link already exists. Left as is.
# Arthur (2011) : link already exists. Left as is.
# Arthur 2: On the Rocks (1988) : link already exists. Left as is.
# Arthur Christmas (2011) : link already exists. Left as is.
# As Above, So Below (2014) : link already exists. Left as is.
# As Good as It Gets (1997) : link already exists. Left as is.
# As I Was Moving Ahead Occasionally I Saw Brief Glimpses of Beauty (2000) : link already exists. Left as is.
# As You Like It (2006) : link already exists. Left as is.
# Ascent, The (Voskhozhdeniye) (1977) : link already exists. Left as is.
# Ashby (2015) : link already exists. Left as is.
# Ashes and Diamonds (Popiól i diament) (1958) : link already exists. Left as is.
# Ashes of Time (Dung che sai duk) (1994) : link already exists. Left as is.
# Ask the Dust (2006) : link already exists. Left as is.
# Aspen Extreme (1993) : link already exists. Left as is.
# Asphalt Jungle, The (1950) : link already exists. Left as is.
# Asphyx, The (1973) : link already exists. Left as is.
# Assassin's Creed (2016) : link already exists. Left as is.
# Assassination (1987) : link already exists. Left as is.
# Assassination Tango (2002) : link already exists. Left as is.
# Assassination of Jesse James by the Coward Robert Ford, The (2007) : link already exists. Left as is.
# Assassination of Richard Nixon, The (2004) : link already exists. Left as is.
# Assassination of a High School President (2008) : link already exists. Left as is.
# Assassins (1995) : link already exists. Left as is.
# Assault on Precinct 13 (1976) : link already exists. Left as is.
# Assault on Precinct 13 (2005) : link already exists. Left as is.
# Assembly (Ji jie hao) (2007)  : link already exists. Left as is.
# Assignment, The (1997) : link already exists. Left as is.
# Asterix & Obelix vs. Caesar (Astérix et Obélix contre César) (1999) : link already exists. Left as is.
# Asterix & Obelix: God Save Britannia (Astérix et Obélix: Au service de Sa Majesté) (2012) : link already exists. Left as is.
# Asterix & Obelix: Mission Cleopatra (Astérix & Obélix: Mission Cléopâtre) (2002) : link already exists. Left as is.
# Asterix and Cleopatra (Astérix et Cléopâtre) (1968) : link already exists. Left as is.
# Asterix and the Vikings (Astérix et les Vikings) (2006) : link already exists. Left as is.
# Asterix at the Olympic Games (Astérix aux jeux olympiques) (2008) : link already exists. Left as is.
# Asterix in America (a.k.a Asterix Conquers America) (Astérix et les Indiens) (1994) : link already exists. Left as is.
# Asterix: The Land of the Gods (Astérix: Le domaine des dieux) (2014) : link already exists. Left as is.
# Astronaut Farmer, The (2007) : link already exists. Left as is.
# Astronaut's Wife, The (1999) : link already exists. Left as is.
# At Close Range (1986) : link already exists. Left as is.
# At First Sight (1999) : link already exists. Left as is.
# At Middleton (2013) : link already exists. Left as is.
# At the Circus (1939) : link already exists. Left as is.
# Atalante, L' (1934) : link already exists. Left as is.
# Atlantic City (1980) : link already exists. Left as is.
# Atlantis: The Lost Empire (2001) : link already exists. Left as is.
# Atlas Shrugged: Part 1 (2011) : link already exists. Left as is.
# Atomic Blonde (2017) : link already exists. Left as is.
# Atomic Brain, The (1963) : link already exists. Left as is.
# Atomic Cafe, The (1982) : link already exists. Left as is.
# Atomic Submarine, The (1959) : link already exists. Left as is.
# Atonement (2007) : link already exists. Left as is.
# Atragon (Kaitei Gunkan) (1963) : link already exists. Left as is.
# Attack of the 50 Foot Woman (1958) : link already exists. Left as is.
# Attack of the Crab Monsters (1957) : link already exists. Left as is.
# Attack of the Giant Leeches (1959) : link already exists. Left as is.
# Attack of the Killer Tomatoes! (1978) : link already exists. Left as is.
# Attack of the Puppet People (1958) : link already exists. Left as is.
# Attack the Block (2011) : link already exists. Left as is.
# Attila (Attila Flagello di Dio) (1982) : link already exists. Left as is.
# Au Hasard Balthazar (1966) : link already exists. Left as is.
# Au revoir les enfants (1987) : link already exists. Left as is.
# Audition (Ôdishon) (1999) : link already exists. Left as is.
# Audrey Rose (1977) : link already exists. Left as is.
# August Rush (2007) : link already exists. Left as is.
# Auntie Mame (1958) : link already exists. Left as is.
# Austenland (2013) : link already exists. Left as is.
# Austin Powers in Goldmember (2002) : link already exists. Left as is.
# Austin Powers: International Man of Mystery (1997) : link already exists. Left as is.
# Austin Powers: The Spy Who Shagged Me (1999) : link already exists. Left as is.
# Australia (2008) : link already exists. Left as is.
# Auto Focus (2002) : link already exists. Left as is.
# Autumn Marathon (1979) : link already exists. Left as is.
# Autumn Sonata (Höstsonaten) (1978) : link already exists. Left as is.
# Autumn Spring (Babí léto) (2001) : link already exists. Left as is.
# Autumn Tale, An (Conte d'automne) (1998) : link already exists. Left as is.
# Autumn in New York (2000) : link already exists. Left as is.
# Autómata (Automata) (2014) : link already exists. Left as is.
# Avalanche (1978) : link already exists. Left as is.
# Avalon (1990) : link already exists. Left as is.
# Avalon (2001) : link already exists. Left as is.
# Avanti! (1972) : link already exists. Left as is.
# Avatar (2009) : link already exists. Left as is.
# Avengers, The (1998) : link already exists. Left as is.
# Avengers, The (2012) : link already exists. Left as is.
# Avengers: Age of Ultron (2015) : link already exists. Left as is.
# Avengers: Infinity War - Part I (2018) : link already exists. Left as is.
# Aviator, The (2004) : link already exists. Left as is.
# Avventura, L' (Adventure, The) (1960) : link already exists. Left as is.
# Awake (2007) : link already exists. Left as is.
# Awakening, The (1980) : link already exists. Left as is.
# Awakenings (1990) : link already exists. Left as is.
# Away We Go (2009) : link already exists. Left as is.
# Away from Her (2006) : link already exists. Left as is.
# Awful Truth, The (1937) : link already exists. Left as is.
# Awfully Big Adventure, An (1995) : link already exists. Left as is.
# Azumi (2003) : link already exists. Left as is.
# B*A*P*S (1997) : link already exists. Left as is.
# B. Monkey (1998) : link already exists. Left as is.
# B/W (2015) : link already exists. Left as is.
# BASEketball (1998) : link already exists. Left as is.
# BMX Bandits (1983) : link already exists. Left as is.
# BURN-E (2008) : link already exists. Left as is.
# Baadasssss! (How to Get the Man's Foot Outta Your Ass) (2003) : link already exists. Left as is.
# Baader Meinhof Komplex, Der (2008) : link already exists. Left as is.
# Baarìa (2009) : link already exists. Left as is.
# Babadook, The (2014) : link already exists. Left as is.
# Babe (1995) : link already exists. Left as is.
# Babe, The (1992) : link already exists. Left as is.
# Babe: Pig in the City (1998) : link already exists. Left as is.
# Babel (2006) : link already exists. Left as is.
# Babes in Toyland (1934) : link already exists. Left as is.
# Babes in Toyland (1961) : link already exists. Left as is.
# Babette's Feast (Babettes gæstebud) (1987) : link already exists. Left as is.
# Baby Boom (1987) : link already exists. Left as is.
# Baby Boy (2001) : link already exists. Left as is.
# Baby Driver (2017) : link already exists. Left as is.
# Baby Geniuses (1999) : link already exists. Left as is.
# Baby Mama (2008) : link already exists. Left as is.
# Baby's Day Out (1994) : link already exists. Left as is.
# Baby, The (1973) : link already exists. Left as is.
# Baby-Sitters Club, The (1995) : link already exists. Left as is.
# Baby... Secret of the Lost Legend (1985) : link already exists. Left as is.
# Babylon 5 : link already exists. Left as is.
# Babylon 5: A Call to Arms (1999) : link already exists. Left as is.
# Babylon 5: In the Beginning (1998) : link already exists. Left as is.
# Babylon 5: The Gathering (1993) : link already exists. Left as is.
# Babylon 5: The Legend of the Rangers: To Live and Die in Starlight (2002) : link already exists. Left as is.
# Babylon 5: The Lost Tales - Voices in the Dark (2007) : link already exists. Left as is.
# Babylon 5: The River of Souls (1998) : link already exists. Left as is.
# Babylon 5: Thirdspace (1998) : link already exists. Left as is.
# Babylon A.D. (2008) : link already exists. Left as is.
# Babysitter, The (1995) : link already exists. Left as is.
# Bachelor Party (1984) : link already exists. Left as is.
# Bachelor and the Bobby-Soxer, The (1947) : link already exists. Left as is.
# Bachelor, The (1999) : link already exists. Left as is.
# Back to School (1986) : link already exists. Left as is.
# Back to the Beach (1987) : link already exists. Left as is.
# Back to the Future (1985) : link already exists. Left as is.
# Back to the Future Part II (1989) : link already exists. Left as is.
# Back to the Future Part III (1990) : link already exists. Left as is.
# Back-up Plan, The (2010) : link already exists. Left as is.
# Backbeat (1993) : link already exists. Left as is.
# Backdraft (1991) : link already exists. Left as is.
# Bad Asses (Bad Ass 2) (2014) : link already exists. Left as is.
# Bad Asses on the Bayou (2015) : link already exists. Left as is.
# Bad Boy Bubby (1993) : link already exists. Left as is.
# Bad Boys (1995) : link already exists. Left as is.
# Bad Boys II (2003) : link already exists. Left as is.
# Bad Company (1995) : link already exists. Left as is.
# Bad Company (2002) : link already exists. Left as is.
# Bad Day at Black Rock (1955) : link already exists. Left as is.
# Bad Education (La mala educación) (2004) : link already exists. Left as is.
# Bad Girls (1994) : link already exists. Left as is.
# Bad Karma (2012) : link already exists. Left as is.
# Bad Lieutenant (1992) : link already exists. Left as is.
# Bad Lieutenant: Port of Call New Orleans (2009) : link already exists. Left as is.
# Bad Milo (Bad Milo!) (2013) : link already exists. Left as is.
# ...
# Lone Star (1996) : link already exists. Left as is.
# Lone Survivor (2013) : added https://m.media-amazon.com/images/M/MV5BMjA0NTgwOTk5Ml5BMl5BanBnXkFtZTcwMjE3NDc5OQ@@._V1_SX300.jpg
# Lonely Are the Brave (1962) : added https://m.media-amazon.com/images/M/MV5BMTViZDU5MDktNjRjYS00Zjk1LThkNmUtMzgwYmRjMmVkZjU3XkEyXkFqcGdeQXVyNTEwNDMwNA@@._V1_SX300.jpg
# Lonely Guy, The (1984) : added https://m.media-amazon.com/images/M/MV5BOTI2ZmQ3ODktYjE2MS00NmVjLTk1MGYtYWYxNmRiMzdlZDI0XkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SX300.jpg
# Lonesome Dove (1989) : added https://m.media-amazon.com/images/M/MV5BMmJmYTg0MDEtN2VjMC00YmUxLWFhNmMtZTBiYjQ2ZGQ5ZWMyXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_SX300.jpg
# Long Day's Journey Into Night (1962) : added https://m.media-amazon.com/images/M/MV5BODNiMjdmYzYtYjQwOC00NWE5LTk5NzktZDUwM2UwNDY4MmM4XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SX300.jpg
# Long Good Friday, The (1980) : added https://m.media-amazon.com/images/M/MV5BMDU2YjI2YjgtODE3OC00N2U1LTgxNjgtMTliYTJjZWMyNTE2XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_SX300.jpg
# Long Goodbye, The (1973) : added https://m.media-amazon.com/images/M/MV5BN2RkZDljODgtMzRjZS00NTg1LTkxNmQtMWE2YWVjZjdhZDg0XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_SX300.jp
# Lucky Break (2001) : added https://m.media-amazon.com/images/M/MV5BMTk5NzM2NTY2Ml5BMl5BanBnXkFtZTcwMTI4NzIyMQ@@._V1_SX300.jpg
# Lucky Number Slevin (2006) : added https://m.media-amazon.com/images/M/MV5BZjczMWI1YWMtYTZjOS00ZDc5LWE2MWItMTY3ZGUxNzFkNjJmL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg
# Lucky One, The (2012) : added https://m.media-amazon.com/images/M/MV5BMTg5NDk3MjAzMF5BMl5BanBnXkFtZTcwMjUyNzExNw@@._V1_SX300.jpg
# Lucky You (2007) : link already exists. Left as is.
# Lucy (2014) : left link as is b/c API returned False because:  Request limit reached!
# API Request limit reached! Aborting the update...

# %% [markdown]
# Now, that we have the df containing the movie information, we can build our two models.
# 1. A non-negative matrix factorization model
# 2. A neighborhood-based collaborative filtering model (using cosine similarity)
#
# Let's talk briefly about the advantages and disadvantages of each model:
#
# The NMF model:
# Advantages: rather fast once set up / implemented. It loves sparsity (gaps) in the data. NMF can work with non-ordinal data.
# Disadvantages: harder to debug (i.e., to understand what's going on).
#
# The NBCFilter model
# Advantages: fast to implement, works for huge dataset, no domain knowledge necessary
# Disadvantages: Hard to include data other than ordinal data (e.g., ratings), Sparsity (i.e., if there's large gaps / NaNs) in data sets, NBCFilter is not great. NMF loves sparsity. Slow for on larger data sets with weak processors

# %% [markdown]
# ## 1. Non-Negative Matrix Factorization model

# %%
# We create the model and store it for later use in our flask app.
model = NMF(n_components=20, init="random", max_iter=10000, random_state=42)
model.fit(df.values)
with open("model_objects/model_nmf" + ".pkl", "wb") as file:
    pickle.dump(model, file)

# %% [markdown]
# ##### Example usage
# Note this is not a necessary pre-processing step, since we will do this in our Flask app class.
#
# For the NMF we need 5 sets of information: U, D, R, P and Q
# U: the set of users
# D: the set of items (here movies)
# R: a user by items (UxD) matrix containing ratings on all the movies.
# Those we have already created earlier.
#
# Now, we define:
# P: a user by latent/hidden features (UxK) matrix
# Q: a items by latent/hidden features (DxK) matrix

# %%
p_mat = model.transform(df.values)
q_mat = model.components_
predictions = np.dot(p_mat, q_mat)

# %% [markdown]
# This is an examaple of how we would **obtain our predictions for a new user**:

# %%
# We just make up a new user with the average ratings of all users 
# (which is our best bet when we don't know the user yet)
# Note, both matrices have already been sorted alphabetically by movie title
new_user = movies_information["avg_ratings_pitem"].values.reshape(1, -1)
# However, to actually get meaningful recommendations, the user needs to have watched and rated a few movies already
# Let's pick 10 movies randomly and create rather high ratings for these movies:
movies_seen = df.sample(n=10, axis=1).columns
ratings_seen = np.random.randint(3, 5, 10).tolist()
print("The user has seen and rated the following: ", movies_seen, ratings_seen)
movies_seen_idx = df.columns.get_indexer(movies_seen)
new_user[0, movies_seen_idx] = ratings_seen
# Get the new user's P matrix...
new_user_p = model.transform(new_user)
# ...and the actual predictions for the ratings of all movies.
new_user_predictions = np.dot(new_user_p, q_mat)
# It's probably better to sort them and find the highest ratings after turning it into a pd.Series:
user_matrix = pd.concat(
    [movies_information, pd.Series(new_user_predictions.flatten(), name="user_predictions")],
    axis=1,
)
print(
    "Top 5 predictions for our new user: ",
    user_matrix.sort_values(by="user_predictions", ascending=False)[:5],
)
# Out:
# The user has seen and rated the following:  Index(['Blind Fury (1989)', 'Last Days of Disco, The (1998)',
#        'Ordinary People (1980)', 'Frozen (2010)', 'To End All Wars (2001)',
#        'Others, The (2001)', 'Ernest & Célestine (Ernest et Célestine) (2012)',
#        'Why Do Fools Fall In Love? (1998)', 'Day of the Jackal, The (1973)',
#        'Bill Burr: I'm Sorry You Feel That Way (2014)'],
#       dtype='object', name='title') [3, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Top 5 predictions for our new user:         imdbId                                        title  \
# 7593  1528313  Nothing to Declare (Rien à déclarer) (2010)
# 6865   824747                            Changeling (2008)
# 3158   240515                   Freddy Got Fingered (2001)
# 7680  1448755                          Killer Elite (2011)
# 8001  2063781                               Smashed (2012)
#
#                        genres  avg_ratings_pitem year_only  \
# 7593                 [Comedy]           3.657620      2010
# 6865  [Crime, Drama, Mystery]           3.658060      2008
# 3158                 [Comedy]           3.643027      2001
# 7680       [Action, Thriller]           3.653993      2011
# 8001          [Comedy, Drama]           3.657620      2012
#
#                                  title_only  \
# 7593  Nothing to Declare (Rien à déclarer)
# 6865                            Changeling
# 3158                   Freddy Got Fingered
# 7680                          Killer Elite
# 8001                               Smashed
#
#                                            poster_links  user_predictions
# 7593  https://m.media-amazon.com/images/M/MV5BMjIxND...          4.037032
# 6865  https://m.media-amazon.com/images/M/MV5BOTA1Mz...          3.948412
# 3158  https://m.media-amazon.com/images/M/MV5BN2Q5Yj...          3.923847
# 7680  https://m.media-amazon.com/images/M/MV5BMTc4MD...          3.904727
# 8001  http://www.interlog.com/~tfs/images/posters/TF...          3.904662

# %% [markdown]
# Now we could do all sorts of recommendations, but before we do, we should remove movies the user has already seen.
# We don't continue with this here because we will do this in the Flask app.

# %% [markdown]
# ## 2. Neighborhood-based collaborative filtering model (using cosine similarity)
#
# For nbcfilter, we don't want to fill all NaNs with averages because we actually want to cluster unseen movies separately from those users have seen. Filling in `0` as a rating for any unseen movie will do just that.

# %%
df_cosim = pd.pivot_table(merged_df, index="userId", columns="title", values="rating")
df_cosim = df_cosim.fillna(0)
# We store this df because we will need it in our FLask app
with open("model_objects/nbcfilter_data" + ".pkl", "wb") as file:
    pickle.dump(df, file)

# %% [markdown]
# ### Example usage
#
# The approach is as follows:
# - We generate a cosine similarity table for all users including our new user
# - Then, we iterate through the new_user's unseen movies and obtain predictions for the new user based on the predictions by otherwise similar users (i.e. neighbors) that have actually seen the unseen movies.

# %%
# We first need to obtain cosine similarity of our data matrix. There is two ways to go about that:
# The manual way with our own functions
cosim_table_manual = create_cosine_table(df_cosim.T)

# The convenient way with sklearn
cosim_table_convenient = cosine_similarity(df_cosim)
cosim_table_convenient = pd.DataFrame(
    cosim_table_convenient, index=df_cosim.index, columns=df_cosim.index
)
# Out:
# 100%|██████████| 610/610 [00:21<00:00, 28.10it/s]

# %% [markdown]
# This is an example of how we would **obtain our predictions for a new user**:

# %%
# The approach for a new user is fairly similar to the NMF model approach initially in that we create a 
# new user with only a certain rating for each movie except for the movies the user has already watched.
# The difference is that we don't use average ratings but 0s (see above)
new_user = np.zeros(np.shape(movies_information["avg_ratings_pitem"]))
movies_seen = movies_information["title"].sample(n=10).tolist()
ratings_seen = np.random.randint(3, 5, 10).tolist()
print("The user has seen and rated the following: ", movies_seen, ratings_seen)
movies_seen_idx = movies_information[movies_information["title"].isin(movies_seen)].index.values
new_user[movies_seen_idx] = list(ratings_seen)
# We now need to add the new user to the df containing all other users and create the cosine_similarity matrix
df_cosim.loc["new_user"] = new_user
cosim_table_convenient_added = cosine_similarity(df_cosim)
cosim_table_convenient_added = pd.DataFrame(
    cosim_table_convenient_added, index=df_cosim.index, columns=df_cosim.index
)
# First, we extract the movie that the user hasn't seen yet
movies_unseen = list(df_cosim.T.index[df_cosim.T["new_user"] == 0])
# Then, we find the highest ranking neighbor/s of our new user.
neighbors = list(
    cosim_table_convenient_added.loc["new_user", :].sort_values(ascending=False).index[1:3]
)  # Note: the first one is the new_user himself, so we need to pick the second

# Finally, we iterate through the new_user's unseen movies and obtain predictions for the new user
# based on the predictions by otherwise similar users (i.e. neighbors) that have actually seen
# the unseen movies.
predicted_ratings_movies = []
for movie in movies_unseen:
    # Find people who watched the unseen movies
    others_seen = list(df_cosim.T.columns[df_cosim.T.loc[movie] > 0])
    numerator = 0
    denominator = 0.000001
    # go through users who are similar but watched the film
    for user in neighbors:
        if user in others_seen:
            # extract the ratings and similarities for similar users
            rating = df_cosim.T.loc[movie, user]
            similarity = cosim_table_convenient_added.loc["new_user", user]
            # predict rating based on the averaged rating of the neighbors
            # sum(ratings)/number of users OR
            # sum(ratings * similarity)/sum(similarities)
            numerator += rating * similarity
            denominator += similarity
    predicted_ratings = round(numerator / denominator, 1)
    predicted_ratings_movies.append([predicted_ratings, movie])
# Transform it into a df and sort it by rating for better viewing
predicted_rating_df = pd.DataFrame(
    predicted_ratings_movies, columns=["user_predictions", "title"]
).sort_values(by="user_predictions", ascending=False)
print(predicted_rating_df)
# Out:
# The user has seen and rated the following:  ['Pitch Perfect (2012)', 'Lost Highway (1997)', 'Better Off Dead... (1985)', 'Hook (1991)', 'Catch That Kid (2004)', 'Maniac (2012)', 'Dana Carvey: Straight White Male, 60 (2016)', 'Twelve Chairs, The (1970)', 'By the Law (1926)', 'Changeling, The (1980)'] [3, 3, 3, 4, 4, 3, 4, 4, 4, 3]
#       user_predictions                                             title
# 5536               5.0                         Me, Myself & Irene (2000)
# 8701               5.0  Three Billboards Outside Ebbing, Missouri (2017)
# 4785               5.0                                    Kingpin (1996)
# 3496               5.0                    Godfather: Part II, The (1974)
# 7415               5.0                           Schindler's List (1993)
# ...                ...                                               ...
# 3241               0.0                               Fright Night (1985)
# 3242               0.0                               Fright Night (2011)
# 3243               0.0                       Fright Night Part II (1988)
# 3244               0.0                           Frighteners, The (1996)
# 9708               0.0         À nous la liberté (Freedom for Us) (1931)
#
# [9709 rows x 2 columns]

# %% [markdown]
# These are the predictions the nbcfilter model would return and we could now do all sorts of recommendations.
